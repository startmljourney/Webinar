# %% [markdown]
# ## Import Libraries

# %%
from keras.preprocessing.image import ImageDataGenerator,  array_to_img, img_to_array, load_img

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Loading the Image

# %%
pixels = Image.open("car.jpg")
plt.imshow(pixels)

# %% [markdown]
# ## Convert Image to Array

# %%
pixel_a=np.asarray(pixels)

# %%
pixel_a.shape
# Out:
# (2400, 3840, 3)

# %% [markdown]
# ### Different Channel of Image
#
# There are different type of channels :
#
# - **RGB** - Red Green Blue
#
# - **CMYK** - Cyan Magenta Yellow Key(Black)
#
# - **HSV** - Hue Saturation Value

# %%
plt.imshow(pixel_a[:,:,0])

# %%
plt.imshow(pixel_a[:,:,1])

# %%
plt.imshow(pixel_a[:,:,2])

# %%
print(pixel_a[:,:,0])
# Out:
# [[182 182 182 ... 159 157 154]
#  [182 182 182 ... 157 155 153]
#  [182 182 182 ... 156 155 154]
#  ...
#  [ 63  63  63 ...  49  48  48]
#  [ 63  63  63 ...  50  50  49]
#  [ 63  63  63 ...  51  50  50]]

# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# image_link : https://images.app.goo.gl/4dSxGcUypHukDV6i8

# %%
# Loading a sample image  
img = load_img('messi.jpg')

# %%
plt.imshow(img)

# %%
# Converting the input sample image to an array 
x = img_to_array(img)

# %%
x.shape
# Out:
# (438, 780, 3)

# %%
# Reshaping the input image 
x = x.reshape((1, ) + x.shape)

# %%
x.shape
# Out:
# (1, 438, 780, 3)

# %% [markdown]
# ## Rotation

# %%
datagen = ImageDataGenerator( 
        rotation_range = 80)

# %%
# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1,
                          save_to_dir ='rotation',  
                          save_prefix ='image', save_format ='jpeg'): 
    i += 1
    if i > 5: 
        break

# %%
image = load_img('rotation/image_0_1407.jpeg') 
plt.imshow(image)

# %% [markdown]
# ## Shearing

# %%
datagen = ImageDataGenerator( 
         
        shear_range = 20)

# %%
# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1,
                          save_to_dir ='Shear',  
                          save_prefix ='image', save_format ='jpeg'): 
    i += 1
    if i > 5: 
        break

# %%
image = load_img('Shear/image_0_695.jpeg') 
plt.imshow(image)

# %% [markdown]
# ## Zoom

# %%
datagen = ImageDataGenerator( 
        zoom_range = 0.2)

# %%
# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1,
                          save_to_dir ='zoom',  
                          save_prefix ='image', save_format ='jpeg'): 
    i += 1
    if i > 5: 
        break

# %%
image = load_img('zoom/image_0_6621.jpeg') 
plt.imshow(image)

# %% [markdown]
# ## Horizontal Flip

# %%
datagen = ImageDataGenerator(  
        horizontal_flip = True)

# %%
# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1,
                          save_to_dir ='horizontal_flip',  
                          save_prefix ='image', save_format ='jpeg'): 
    i += 1
    if i > 5: 
        break

# %%
image = load_img('horizontal_flip/image_0_6196.jpeg') 
plt.imshow(image)
